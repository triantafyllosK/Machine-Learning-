# %% [markdown]
# # Import pandas

# %%
import pandas as pd

# %% [markdown]
# # Create a series of three different colours

# %%
colours=pd.Series(["Blue","Red","Green"])
colours
# Out:
# 0     Blue
# 1      Red
# 2    Green
# dtype: object

# %% [markdown]
# # View the series of different colours

# %%
car_colours=pd.DataFrame(car)
car_colours
# Out:
#        0
# 0   Fiat
# 1  HOnda
# 2    BMW

# %% [markdown]
# # Create a series of three different car types and view it

# %%
car=pd.Series(["Fiat","HOnda","BMW"])
car
# Out:
# 0     Fiat
# 1    HOnda
# 2      BMW
# dtype: object

# %% [markdown]
# # Combine the Series of cars and colours into a DataFrame

# %%
car_data=pd.DataFrame({"Cars": car, "Colour":colours})
car_data
# Out:
#     Cars Colour
# 0   Fiat   Blue
# 1  HOnda    Red
# 2    BMW  Green

# %%
# Read the csv files
car_sales = pd.read_csv("car-sales-extended.csv")
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
#We check the dates we have
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           1000 non-null   object
#  1   Colour         1000 non-null   object
#  2   Odometer (KM)  1000 non-null   int64
#  3   Doors          1000 non-null   int64
#  4   Price          1000 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %%
#Statistical analysis , average of your numerical colums 
car_sales.mean()
# Out:
# Odometer (KM)    131073.708
# Doors                 4.014
# Price             16045.665
# dtype: float64

# %%
# We check the price of the cars and find the average
car_prices= pd.Series([3000, 1500, 111250])
car_prices.mean()
# Out:
# 38583.333333333336

# %%
#we make sum to at series
car_sales.sum()
# Out:
# Make             HondaBMWHondaToyotaNissanHondaToyotaHondaNissa...
# Colour           WhiteBlueWhiteWhiteBlueRedBlueWhiteWhiteBlueWh...
# Odometer (KM)                                            131073708
# Doors                                                         4014
# Price                                                     16045665
# dtype: object

# %%
# we call the sum of Doors
car_sales["Doors"].sum()
# Out:
# 4014

# %%
# we check the row length 
len(car_sales)
# Out:
# 1000

# %%
 car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## Viewing and selecting Data

# %%
# give a quick snapshot at the data frame contains
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434
# 4  Nissan   Blue         181577      3  14043

# %%
# give number if you need more rows frames 
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434
# 4  Nissan   Blue         181577      3  14043
# 5   Honda    Red          42652      4  23883
# 6  Toyota   Blue         163453      4   8473

# %%
# .loc & .iloc
animals = pd.Series(["cat", "dog", "pandas","snake"])
animals
# Out:
# 0       cat
# 1       dog
# 2    pandas
# 3     snake
# dtype: object

# %%
# we give extra row to the table animals
animals = pd.Series(["cat", "dog", "pandas","snake"],index=[0,3,9,8])
animals
# Out:
# 0       cat
# 3       dog
# 9    pandas
# 8     snake
# dtype: object

# %%
# choose the columns 3
animals.loc[3]
# Out:
# 'dog'

# %%
# choose the columns 3
car_sales.loc[3]
# Out:
# Make             Toyota
# Colour            White
# Odometer (KM)    154365
# Doors                 4
# Price             13434
# Name: 3, dtype: object

# %%
# .iloc refers to position 
animals.iloc[3]
# Out:
# 'snake'

# %%
animals.iloc[0]
# Out:
# 'cat'

# %%
car_sales.iloc[2]
# Out:
# Make             Honda
# Colour           White
# Odometer (KM)    84714
# Doors                4
# Price            28343
# Name: 2, dtype: object

# %%
# give us up to and including index three
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434

# %%
# select a column
car_sales["Make"]
# Out:
# 0       Honda
# 1         BMW
# 2       Honda
# 3      Toyota
# 4      Nissan
#         ...
# 995    Toyota
# 996    Nissan
# 997    Nissan
# 998     Honda
# 999    Toyota
# Name: Make, Length: 1000, dtype: object

# %%
# this is same like previes but we can't use it if we have space between the words
car_sales.Make
# Out:
# 0       Honda
# 1         BMW
# 2       Honda
# 3      Toyota
# 4      Nissan
#         ...
# 995    Toyota
# 996    Nissan
# 997    Nissan
# 998     Honda
# 999    Toyota
# Name: Make, Length: 1000, dtype: object

# %%
car_sales["Odometer (KM)"]
# Out:
# 0       35431
# 1      192714
# 2       84714
# 3      154365
# 4      181577
#         ...
# 995     35820
# 996    155144
# 997     66604
# 998    215883
# 999    248360
# Name: Odometer (KM), Length: 1000, dtype: int64

# %%
car_sales.Odometer (KM)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9308/240837061.py in <module>
# ----> 1 car_sales.Odometer (KM)
#
# ~\Desktop\ML_project_1\envs\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Odometer'

# %%
# boolean indexing
car_sales[car_sales["Make"]== "Toyota"]
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 3    Toyota  White         154365      4  13434
# 6    Toyota   Blue         163453      4   8473
# 15   Toyota   Blue         205592      4  16290
# 16   Toyota    Red          96742      4  34465
# 20   Toyota   Blue         124844      4  24130
# ..      ...    ...            ...    ...    ...
# 983  Toyota    Red         183330      4  14671
# 989  Toyota    Red          41735      4  13928
# 990  Toyota  White         173408      4   8082
# 995  Toyota  Black          35820      4  32042
# 999  Toyota   Blue         248360      4  12732
#
# [398 rows x 5 columns]

# %%
car_sales[car_sales["Odometer (KM)"] <= 50000]
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 5     Honda    Red          42652      4  23883
# 7     Honda  White          43120      4  20306
# 11   Nissan  Green          17119      4   6160
# 21    Honda   Blue          30615      4  29653
# ..      ...    ...            ...    ...    ...
# 969     BMW   Blue          45207      5  35254
# 975   Honda  White          22409      4  10429
# 979  Toyota  Black          17975      4  17940
# 989  Toyota    Red          41735      4  13928
# 995  Toyota  Black          35820      4  32042
#
# [167 rows x 5 columns]

# %%
# Kind of data you'll come across
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors    3    4   5
# Make
# BMW     21    0  79
# Honda    0  304   0
# Nissan  44  154   0
# Toyota   0  398   0

# %%
# Groupby
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)     Doors         Price
# Make
# BMW     123540.800000  4.580000  27089.830000
# Honda   124667.671053  4.000000  14514.200658
# Nissan  135480.308081  3.777778  13658.368687
# Toyota  135667.223618  4.000000  15628.160804

# %%
# if the plot is not show we must write:
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot()

# %%
car_sales["Odometer (KM)"].hist()

# %%
car_sales["Price"].plot()

# %%
# how to convert a pandas column price to integer
#car_sales["Price"] = car_sales["Price"].str.replace('[\$\,]|', '').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9308/2815776932.py in <module>
#       1 # how to convert a pandas column price to integer
# ----> 2 car_sales["Price"] = car_sales["Price"].str.replace('[\$\,]|', '').astype(int)
#
# ~\Desktop\ML_project_1\envs\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Desktop\ML_project_1\envs\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
# ...

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0       honda
# 1         bmw
# 2       honda
# 3      toyota
# 4      nissan
#         ...
# 995    toyota
# 996    nissan
# 997    nissan
# 998     honda
# 999    toyota
# Name: Make, Length: 1000, dtype: object

# %%
# if we want to saved the values we need to reassign 
car_sales["Make"]= car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     honda  White          35431      4  15323
# 1       bmw   Blue         192714      5  19943
# 2     honda  White          84714      4  28343
# 3    toyota  White         154365      4  13434
# 4    nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  toyota  Black          35820      4  32042
# 996  nissan  White         155144      3   5716
# 997  nissan   Blue          66604      4  31570
# 998   honda  White         215883      4   4001
# 999  toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
# place parameter and missing data
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# we check the value 
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
# we fill the missing column ,data frames, with the value 92302.66666667
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# pandas how to fill missing data in a column
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
#Same like previes
car_sales_missing["Odometer"]= car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
# Dropping axis labels with missing data
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
# To save the dropna we must write inplace = True
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %% [markdown]
# # to reimport the values we drop out

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
# creative new csv file with new values
car_sales_missing_dropped.to_csv("car_sales_missing_dropped.csv")

# %%
# Column from series
seats_column= pd.Series([5,5,5,5,5])

# New column called seats
car_sales["Seats"] = seats_column
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price  Seats
# 0     honda  White          35431      4  15323    5.0
# 1       bmw   Blue         192714      5  19943    5.0
# 2     honda  White          84714      4  28343    5.0
# 3    toyota  White         154365      4  13434    5.0
# 4    nissan   Blue         181577      3  14043    5.0
# ..      ...    ...            ...    ...    ...    ...
# 995  toyota  Black          35820      4  32042    NaN
# 996  nissan  White         155144      3   5716    NaN
# 997  nissan   Blue          66604      4  31570    NaN
# 998   honda  White         215883      4   4001    NaN
# 999  toyota   Blue         248360      4  12732    NaN
#
# [1000 rows x 6 columns]

# %%
#Fill the NaN values with 5 
car_sales["Seats"].fillna(5, inplace=True)
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price  Seats
# 0     honda  White          35431      4  15323    5.0
# 1       bmw   Blue         192714      5  19943    5.0
# 2     honda  White          84714      4  28343    5.0
# 3    toyota  White         154365      4  13434    5.0
# 4    nissan   Blue         181577      3  14043    5.0
# ..      ...    ...            ...    ...    ...    ...
# 995  toyota  Black          35820      4  32042    5.0
# 996  nissan  White         155144      3   5716    5.0
# 997  nissan   Blue          66604      4  31570    5.0
# 998   honda  White         215883      4   4001    5.0
# 999  toyota   Blue         248360      4  12732    5.0
#
# [1000 rows x 6 columns]

# %%
# Column from Python List. Must be same length as your existing data frame, whereas a series can be
fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7,5.0,6.4,8.0,4.5,7.0]
car_sales_missing["Fuel per 100KM"] = fuel_economy
fuel_economy
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price  Fuel per 100KM
# 0  Toyota  White  150043.0    4.0   $4,000             7.5
# 1   Honda    Red   87899.0    4.0   $5,000             9.2
# 2  Toyota   Blue       NaN    3.0   $7,000             5.0
# 3     BMW  Black   11179.0    5.0  $22,000             9.6
# 4  Nissan  White  213095.0    4.0   $3,500             8.7
# 5  Toyota  Green       NaN    4.0   $4,500             5.0
# 6   Honda    NaN       NaN    4.0   $7,500             6.4
# 7   Honda   Blue       NaN    4.0      NaN             8.0
# 8  Toyota  White   60000.0    NaN      NaN             4.5
# 9     NaN  White   31600.0    4.0   $9,700             7.0

# %%
car_sales_2022 = pd.read_csv("car-sales_2022.csv")
car_sales_2022
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_2022["Fuel per 100KM"] = fuel_economy
car_sales_2022
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Fuel per 100KM
# 0  Toyota  White         150043      4   $4,000.00             7.5
# 1   Honda    Red          87899      4   $5,000.00             9.2
# 2  Toyota   Blue          32549      3   $7,000.00             5.0
# 3     BMW  Black          11179      5  $22,000.00             9.6
# 4  Nissan  White         213095      4   $3,500.00             8.7
# 5  Toyota  Green          99213      4   $4,500.00             5.0
# 6   Honda   Blue          45698      4   $7,500.00             6.4
# 7   Honda   Blue          54738      4   $7,000.00             8.0
# 8  Toyota  White          60000      4   $6,250.00             4.5
# 9  Nissan  White          31600      4   $9,700.00             7.0

# %%
# We divided the odometer column by a Fuel per 100KM, we can find the litres of fuel this car is used in its whole entire life
car_sales_2022["Total fuel used (L)"]= car_sales_2022["Odometer (KM)"]/100*car_sales_2022["Fuel per 100KM"]
car_sales_2022
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00             7.5
# 1   Honda    Red          87899      4   $5,000.00             9.2
# 2  Toyota   Blue          32549      3   $7,000.00             5.0
# 3     BMW  Black          11179      5  $22,000.00             9.6
# 4  Nissan  White         213095      4   $3,500.00             8.7
# 5  Toyota  Green          99213      4   $4,500.00             5.0
# 6   Honda   Blue          45698      4   $7,500.00             6.4
# 7   Honda   Blue          54738      4   $7,000.00             8.0
# 8  Toyota  White          60000      4   $6,250.00             4.5
# 9  Nissan  White          31600      4   $9,700.00             7.0
#
#    Total fuel used  Total fuel used (L)
# 0        11253.225            11253.225
# 1         8086.708             8086.708
# 2         1627.450             1627.450
# 3         1073.184             1073.184
# ...

# %%
# Create a column from a single value
car_sales_2022["Number of wheels"]= 4
car_sales_2022
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00             7.5
# 1   Honda    Red          87899      4   $5,000.00             9.2
# 2  Toyota   Blue          32549      3   $7,000.00             5.0
# 3     BMW  Black          11179      5  $22,000.00             9.6
# 4  Nissan  White         213095      4   $3,500.00             8.7
# 5  Toyota  Green          99213      4   $4,500.00             5.0
# 6   Honda   Blue          45698      4   $7,500.00             6.4
# 7   Honda   Blue          54738      4   $7,000.00             8.0
# 8  Toyota  White          60000      4   $6,250.00             4.5
# 9  Nissan  White          31600      4   $9,700.00             7.0
#
#    Total fuel used  Total fuel used (L)  Number of wheels
# 0        11253.225            11253.225                 4
# 1         8086.708             8086.708                 4
# ...

# %%
car_sales_2022["Passed orad saftey"]=True
car_sales_2022.dtypes
car_sales_2022
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00             7.5
# 1   Honda    Red          87899      4   $5,000.00             9.2
# 2  Toyota   Blue          32549      3   $7,000.00             5.0
# 3     BMW  Black          11179      5  $22,000.00             9.6
# 4  Nissan  White         213095      4   $3,500.00             8.7
# 5  Toyota  Green          99213      4   $4,500.00             5.0
# 6   Honda   Blue          45698      4   $7,500.00             6.4
# 7   Honda   Blue          54738      4   $7,000.00             8.0
# 8  Toyota  White          60000      4   $6,250.00             4.5
# 9  Nissan  White          31600      4   $9,700.00             7.0
#
#    Total fuel used  Total fuel used (L)  Number of wheels  Passed orad saftey
# 0        11253.225            11253.225                 4                True
# ...

# %%
#Remove one column
car_sales_2022 = car_sales_2022.drop("Total fuel used",axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9308/70868503.py in <module>
#       1 #Remove one column
# ----> 2 car_sales_2022=car_sales_2022.drop("Total fuel used",axis=1)
#
# ~\Desktop\ML_project_1\envs\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4313             level=level,
#    4314             inplace=inplace,
# -> 4315             errors=errors,
#    4316         )
#    4317
#
# ~\Desktop\ML_project_1\envs\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
car_sales_2022
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Fuel per 100KM  \
# 0  Toyota  White         150043      4   $4,000.00             7.5
# 1   Honda    Red          87899      4   $5,000.00             9.2
# 2  Toyota   Blue          32549      3   $7,000.00             5.0
# 3     BMW  Black          11179      5  $22,000.00             9.6
# 4  Nissan  White         213095      4   $3,500.00             8.7
# 5  Toyota  Green          99213      4   $4,500.00             5.0
# 6   Honda   Blue          45698      4   $7,500.00             6.4
# 7   Honda   Blue          54738      4   $7,000.00             8.0
# 8  Toyota  White          60000      4   $6,250.00             4.5
# 9  Nissan  White          31600      4   $9,700.00             7.0
#
#    Total fuel used (L)  Number of wheels  Passed orad saftey
# 0            11253.225                 4                True
# 1             8086.708                 4                True
# ...
